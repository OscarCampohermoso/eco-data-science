# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import auxiliares5 as aux

# %%
# Meses de finalización de cada trimestre
meses_trimestres = ['03', '06', '09', '12']
años = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023']

# Empresa a buscar
empresa_busqueda = 'CENCOSUD S.A.'

# DataFrame para recopilar todos los datos
datos_totales = pd.DataFrame()

for año in años:
    for mes in meses_trimestres:
        df_trimestral = aux.obtener_datos_trimestrales(mes, año, empresa_busqueda)
        print(df_trimestral)
        datos_totales = pd.concat([datos_totales, df_trimestral], ignore_index=True)

print(datos_totales)
# Out:
#   Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                  2013-03-31   30/05/2013 11:31   30/05/2013 11:33
#   Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                  2013-06-30   30/08/2013 17:07   30/08/2013 17:07
#   Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                  2013-09-30   15/11/2013 19:48   15/11/2013 19:48
#   Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                  2013-12-31   28/03/2014 17:12   28/03/2014 17:12
#   Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                  2014-03-31   27/05/2014 18:25   27/05/2014 18:25
#   Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                  2014-06-30   05/09/2014 12:41   11/09/2014 10:46
#   Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                  2014-09-30   28/11/2014 17:05   28/11/2014 17:05
# ...

# %%
# Guardar todos los datos en la base de datos
aux.guardar_datos(datos_totales)

# %%
datos_totales
# Out:
#    Trimestre_Estado_Financiero Fecha_Primer_envio Fecha_ultimo_envio
# 0                   2013-03-31   30/05/2013 11:31   30/05/2013 11:33
# 1                   2013-06-30   30/08/2013 17:07   30/08/2013 17:07
# 2                   2013-09-30   15/11/2013 19:48   15/11/2013 19:48
# 3                   2013-12-31   28/03/2014 17:12   28/03/2014 17:12
# 4                   2014-03-31   27/05/2014 18:25   27/05/2014 18:25
# 5                   2014-06-30   05/09/2014 12:41   11/09/2014 10:46
# 6                   2014-09-30   28/11/2014 17:05   28/11/2014 17:05
# 7                   2014-12-31   27/03/2015 17:09   27/03/2015 17:09
# 8                   2015-03-31   29/05/2015 17:01   29/05/2015 21:14
# 9                   2015-06-30   28/08/2015 08:47   02/09/2015 10:32
# 10                  2015-09-30   27/11/2015 18:06   27/11/2015 18:06
# 11                  2015-12-31   03/03/2016 17:14   03/03/2016 17:14
# 12                  2016-03-31   25/05/2016 17:36   26/05/2016 10:25
# ...
